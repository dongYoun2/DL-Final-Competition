# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import PIL as Image

# %%
image_list = 'data/Open_Images/open_images_image_list.txt'
df = pd.read_csv(image_list, header=None, sep='/')
df.columns = ['split', 'image_id']

df.head()
# Out:
#         split          image_id
# 0  validation  fe600639ac5f36c1
# 1  validation  ba82c70cc6cdf449
# 2  validation  e3ffa4c868b11b15
# 3  validation  7d00af2927a57eeb
# 4  validation  914dd6fb5eb17e85
